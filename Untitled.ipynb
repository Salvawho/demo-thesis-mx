# %%
import pandas as pd

df = pd.read_csv("uber-raw-data-sep14.csv.gz")

# %%
df.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  9/1/2014 0:01:00  40.2201 -74.0021  B02512
# 1  9/1/2014 0:01:00  40.7500 -74.0027  B02512
# 2  9/1/2014 0:03:00  40.7559 -73.9864  B02512
# 3  9/1/2014 0:06:00  40.7450 -73.9889  B02512
# 4  9/1/2014 0:11:00  40.8145 -73.9444  B02512

# %%
df.tail()
# Out:
#                   Date/Time      Lat      Lon    Base
# 1028131  9/30/2014 22:57:00  40.7668 -73.9845  B02764
# 1028132  9/30/2014 22:57:00  40.6911 -74.1773  B02764
# 1028133  9/30/2014 22:58:00  40.8519 -73.9319  B02764
# 1028134  9/30/2014 22:58:00  40.7081 -74.0066  B02764
# 1028135  9/30/2014 22:58:00  40.7140 -73.9496  B02764

# %%
df2 = pd.read_csv("dataset_PF.csv")

# %%
df2.head()
# Out:
#     ID Fecha_Publicacion Fecha_Incidente  Categoria Publicacion  \
# 0  1.0          02/01/16        1/1/2016   Balacera      Sábado
# 1  2.0          09/01/16        1/8/2016     Asalto      Sábado
# 2  3.0          10/01/16        1/9/2016     Asalto     Domingo
# 3  4.0          16/01/16       1/14/2016       Robo      Sábado
# 4  5.0          19/01/16       1/18/2016  Ejecución      Martes
#
#   Distrito_Policiaco                           Direccion   Hora    Latitud  \
# 0           Veracruz              Rincón Brujo, Maltrata   3:00        NaN
# 1           Veracruz          Magueyes, Maltrata km. 239  23:00  18.829573
# 2           Veracruz  Puerto del Aire, Acultzingo km. 34  18:00  18.699543
# 3           Veracruz                 Nogales - Huiloapan   3:00        NaN
# 4             Puebla             Boca del Monte, km. 225  14:30  18.832306
#
#     Longitud  ... Unnamed: 17  Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# ...

# %%
media_lat = df2['Latitud'].mean()
print(media_lat)
# Out:
# 18.82591902877696

# %%
df2['Latitud'].fillna(media_lat, inplace = True)

# %%
media_lon = df2['Longitud'].mean()
df2['Longitud'].fillna(media_lon, inplace=True)

# %%
df2.head()
# Out:
#     ID Fecha_Publicacion Fecha_Incidente  Categoria Publicacion  \
# 0  1.0          02/01/16        1/1/2016   Balacera      Sábado
# 1  2.0          09/01/16        1/8/2016     Asalto      Sábado
# 2  3.0          10/01/16        1/9/2016     Asalto     Domingo
# 3  4.0          16/01/16       1/14/2016       Robo      Sábado
# 4  5.0          19/01/16       1/18/2016  Ejecución      Martes
#
#   Distrito_Policiaco                           Direccion   Hora    Latitud  \
# 0           Veracruz              Rincón Brujo, Maltrata   3:00  18.825919
# 1           Veracruz          Magueyes, Maltrata km. 239  23:00  18.829573
# 2           Veracruz  Puerto del Aire, Acultzingo km. 34  18:00  18.699543
# 3           Veracruz                 Nogales - Huiloapan   3:00  18.825919
# 4             Puebla             Boca del Monte, km. 225  14:30  18.832306
#
#     Longitud  ... Unnamed: 17  Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# ...

# %%
df2.rename(columns={'Latitud': 'Lat', 'Longitud':'Lon', 'Fecha_Incidente': 'Date/Time'}, inplace=True)
df2.head()
# Out:
#     ID Fecha_Publicacion  Date/Time  Categoria Publicacion Distrito_Policiaco  \
# 0  1.0          02/01/16   1/1/2016   Balacera      Sábado           Veracruz
# 1  2.0          09/01/16   1/8/2016     Asalto      Sábado           Veracruz
# 2  3.0          10/01/16   1/9/2016     Asalto     Domingo           Veracruz
# 3  4.0          16/01/16  1/14/2016       Robo      Sábado           Veracruz
# 4  5.0          19/01/16  1/18/2016  Ejecución      Martes             Puebla
#
#                             Direccion   Hora        Lat        Lon  ...  \
# 0              Rincón Brujo, Maltrata   3:00  18.825919 -97.243275  ...
# 1          Magueyes, Maltrata km. 239  23:00  18.829573 -97.255900  ...
# 2  Puerto del Aire, Acultzingo km. 34  18:00  18.699543 -97.336793  ...
# 3                 Nogales - Huiloapan   3:00  18.825919 -97.243275  ...
# 4             Boca del Monte, km. 225  14:30  18.832306 -97.329236  ...
#
# ...

# %%
df2 = df2.drop(columns=['Fecha_Publicacion', 'Distrito_Policiaco', 'Direccion', 'Unnamed: 17'])
df2
# Out:
#       ID  Date/Time  Categoria Publicacion   Hora        Lat        Lon  \
# 0    1.0   1/1/2016   Balacera      Sábado   3:00  18.825919 -97.243275
# 1    2.0   1/8/2016     Asalto      Sábado  23:00  18.829573 -97.255900
# 2    3.0   1/9/2016     Asalto     Domingo  18:00  18.699543 -97.336793
# 3    4.0  1/14/2016       Robo      Sábado   3:00  18.825919 -97.243275
# 4    5.0  1/18/2016  Ejecución      Martes  14:30  18.832306 -97.329236
# ..   ...        ...        ...         ...    ...        ...        ...
# 992  NaN        NaN        NaN         NaN    NaN  18.825919 -97.243275
# 993  NaN        NaN        NaN         NaN    NaN  18.825919 -97.243275
# 994  NaN        NaN        NaN         NaN    NaN  18.825919 -97.243275
# 995  NaN        NaN        NaN         NaN    NaN  18.825919 -97.243275
# 996  NaN        NaN        NaN         NaN    NaN  18.825919 -97.243275
#
#                Coordenadas  Arrestos                           Descripcion  \
# ...

# %%
df2 = df2.drop(columns=df2.columns[7::])

# %%
df2.head()
# Out:
#     ID  Date/Time  Categoria Publicacion   Hora        Lat        Lon
# 0  1.0   1/1/2016   Balacera      Sábado   3:00  18.825919 -97.243275
# 1  2.0   1/8/2016     Asalto      Sábado  23:00  18.829573 -97.255900
# 2  3.0   1/9/2016     Asalto     Domingo  18:00  18.699543 -97.336793
# 3  4.0  1/14/2016       Robo      Sábado   3:00  18.825919 -97.243275
# 4  5.0  1/18/2016  Ejecución      Martes  14:30  18.832306 -97.329236

# %%
df2 = df2.drop(index=df2.index[509::])

# %%
df2.tail()
# Out:
#         ID   Date/Time Categoria Publicacion   Hora        Lat        Lon
# 504  505.0         NaN      Robo      Jueves   3:00  18.825919 -97.243275
# 505  506.0  11/20/2019      Robo     Viernes  20:00  18.825919 -97.243275
# 506  507.0  11/22/2019      Robo      Sábado  23:00  18.829573 -97.255900
# 507  508.0  11/30/2019      Robo      Martes   9:00  18.825919 -97.243275
# 508  509.0  12/15/2019    Asalto       Lunes  12:00  18.825919 -97.243275

# %%
df2['Date/Time'] = df2['Date/Time'].fillna(df2['Date/Time'].shift())
df2.head()
# Out:
#     ID  Date/Time  Categoria Publicacion   Hora        Lat        Lon
# 0  1.0   1/1/2016   Balacera      Sábado   3:00  18.825919 -97.243275
# 1  2.0   1/8/2016     Asalto      Sábado  23:00  18.829573 -97.255900
# 2  3.0   1/9/2016     Asalto     Domingo  18:00  18.699543 -97.336793
# 3  4.0  1/14/2016       Robo      Sábado   3:00  18.825919 -97.243275
# 4  5.0  1/18/2016  Ejecución      Martes  14:30  18.832306 -97.329236

# %%
df2['Date/Time'] = pd.to_datetime(df2['Date/Time'] + ' ' + df2['Hora'])
df2.head()
# Out:
#     ID           Date/Time  Categoria Publicacion   Hora        Lat        Lon
# 0  1.0 2016-01-01 03:00:00   Balacera      Sábado   3:00  18.825919 -97.243275
# 1  2.0 2016-01-08 23:00:00     Asalto      Sábado  23:00  18.829573 -97.255900
# 2  3.0 2016-01-09 18:00:00     Asalto     Domingo  18:00  18.699543 -97.336793
# 3  4.0 2016-01-14 03:00:00       Robo      Sábado   3:00  18.825919 -97.243275
# 4  5.0 2016-01-18 14:30:00  Ejecución      Martes  14:30  18.832306 -97.329236

# %%
df2 = df2.drop(columns=['Categoria'])
df2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-d7a75cb31bc3> in <module>
# ----> 1 df2 = df2.drop(columns=['Categoria'])
#       2 df2.head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df2.head()
# Out:
#             Date/Time        Lat        Lon
# 0 2016-01-01 03:00:00  18.825919 -97.243275
# 1 2016-01-08 23:00:00  18.829573 -97.255900
# 2 2016-01-09 18:00:00  18.699543 -97.336793
# 3 2016-01-14 03:00:00  18.825919 -97.243275
# 4 2016-01-18 14:30:00  18.832306 -97.329236

# %%
df2['Date/Time'] = df2['Date/Time'].dt.strftime('%m/%d/%Y %H:%M:%S')
df2
# Out:
#                Date/Time        Lat        Lon
# 0    01/01/2016 03:00:00  18.825919 -97.243275
# 1    01/08/2016 23:00:00  18.829573 -97.255900
# 2    01/09/2016 18:00:00  18.699543 -97.336793
# 3    01/14/2016 03:00:00  18.825919 -97.243275
# 4    01/18/2016 14:30:00  18.832306 -97.329236
# ..                   ...        ...        ...
# 504  11/17/2019 03:00:00  18.825919 -97.243275
# 505  11/20/2019 20:00:00  18.825919 -97.243275
# 506  11/22/2019 23:00:00  18.829573 -97.255900
# 507  11/30/2019 09:00:00  18.825919 -97.243275
# 508  12/15/2019 12:00:00  18.825919 -97.243275
#
# [509 rows x 3 columns]

# %%
columnas = []

# %%
columnas = ['id', 'apellido', 'nombre', 'edad']

# %%
df.tail()
# Out:
#                   Date/Time      Lat      Lon    Base
# 1028131  9/30/2014 22:57:00  40.7668 -73.9845  B02764
# 1028132  9/30/2014 22:57:00  40.6911 -74.1773  B02764
# 1028133  9/30/2014 22:58:00  40.8519 -73.9319  B02764
# 1028134  9/30/2014 22:58:00  40.7081 -74.0066  B02764
# 1028135  9/30/2014 22:58:00  40.7140 -73.9496  B02764

# %%
df2.to_csv('fullData.csv', index=False)
